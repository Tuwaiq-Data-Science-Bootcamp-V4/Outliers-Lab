# %% [markdown]
# ### Import your librares

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Load your dataset

# %%
df = pd.read_csv('seattle_weather.csv')
df
# Out:
#              DATE  PRCP  TMAX  TMIN   RAIN
# 0      1948-01-01  0.47    51    42   True
# 1      1948-01-02  0.59    45    36   True
# 2      1948-01-03  0.42    45    35   True
# 3      1948-01-04  0.31    45    34   True
# 4      1948-01-05  0.17    45    32   True
# ...           ...   ...   ...   ...    ...
# 25546  2017-12-10  0.00    49    34  False
# 25547  2017-12-11  0.00    49    29  False
# 25548  2017-12-12  0.00    46    32  False
# 25549  2017-12-13  0.00    48    34  False
# 25550  2017-12-14  0.00    50    36  False
#
# [25551 rows x 5 columns]

# %% [markdown]
# ### Handle missing data in PRCP and RAIN columns

# %%
df.dropna(inplace = True)
df.reset_index(inplace = True, drop = True)
df
# Out:
#              DATE  PRCP  TMAX  TMIN   RAIN
# 0      1948-01-01  0.47    51    42   True
# 1      1948-01-02  0.59    45    36   True
# 2      1948-01-03  0.42    45    35   True
# 3      1948-01-04  0.31    45    34   True
# 4      1948-01-05  0.17    45    32   True
# ...           ...   ...   ...   ...    ...
# 25543  2017-12-10  0.00    49    34  False
# 25544  2017-12-11  0.00    49    29  False
# 25545  2017-12-12  0.00    46    32  False
# 25546  2017-12-13  0.00    48    34  False
# 25547  2017-12-14  0.00    50    36  False
#
# [25548 rows x 5 columns]

# %% [markdown]
# ### Repeat the following steps for each column within outliers
#
# * Visualize the outliers
# * Detect if your data set contains any outliers
# * Identify lower & higher limit of outliers
# * Drop all outliers
# * Visualize the column after processing

# %% [markdown]
# ## PRCP

# %%
sns.boxplot(data = df, y = 'PRCP');

# %%
Q1 = np.percentile(df['PRCP'], 25, interpolation = 'midpoint')
Q3 = np.percentile(df['PRCP'], 75, interpolation = 'midpoint')
IQR = Q3 - Q1
               
print('lower bound outliers for PRCP ', Q1 - 1.5 * (IQR))
print('higher bound outliers for PRCP', Q3 + 1.5 * (IQR))
# Out:
# lower bound outliers for PRCP  -0.15000000000000002
# higher bound outliers for PRCP 0.25

# %%
df = df.drop(df[(df['PRCP'] > 0.25) | (df['PRCP'] < -0.15000000000000002)].index)

# %%
sns.boxplot(data = df, y = 'PRCP');

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# ## TMAX

# %%
sns.boxplot(data = df, y = 'TMAX');

# %%
Q1 = np.percentile(df['TMAX'], 25, interpolation = 'midpoint')
Q3 = np.percentile(df['TMAX'], 75, interpolation = 'midpoint')
IQR = Q3 - Q1
               
print('lower bound outliers for TMAX ', Q1 - 1.5 * (IQR))
print('higher bound outliers for TMAX', Q3 + 1.5 * (IQR))
# Out:
# lower bound outliers for TMAX  20.0
# higher bound outliers for TMAX 100.0

# %%
df = df.drop(df[(df['TMAX'] > 100.0) | (df['TMAX'] < 20.0)].index)

# %%
sns.boxplot(data = df, y = 'TMAX');

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# ## TMIN

# %%
sns.boxplot(data = df, y = 'TMIN');

# %%
Q1 = np.percentile(df['TMIN'], 25, interpolation = 'midpoint')
Q3 = np.percentile(df['TMIN'], 75, interpolation = 'midpoint')
IQR = Q3 - Q1
               
print('lower bound outliers for TMIN ', Q1 - 1.5 * (IQR))
print('higher bound outliers for TMIN', Q3 + 1.5 * (IQR))
# Out:
# lower bound outliers for TMIN  17.0
# higher bound outliers for TMIN 73.0

# %%
df = df.drop(df[(df['TMIN'] > 73.0) | (df['TMIN'] < 17.0)].index)

# %%
sns.boxplot(data = df, y = 'TMIN');

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# ## All column after process

# %%
sns.boxplot(data = df);
